# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow.keras as keras
import keras.layers as layers
from sklearn.model_selection import train_test_split
import random
import tensorflow_probability as tfp
import tensorflow_addons as tfa

# %% [markdown]
# # **Data Augmentation**

# %%
from tensorflow.keras.preprocessing import image_dataset_from_directory
from keras import backend as K

batch_size= 24
image_size = [128, 128]


ds = image_dataset_from_directory(
    '../input/screwanomalies-detection/screw/train',
    labels=None,
    image_size=image_size,
    interpolation='nearest',
    batch_size=batch_size,
    shuffle=True,
)

def convert_to_float(image):
    image = tf.image.convert_image_dtype(image, dtype=tf.float32)
    return image


def trans1(img):
    return tfa.image.rotate(tf.image.flip_left_right(tf.image.flip_up_down(img)),-.2,fill_mode="reflect",interpolation="bilinear")

def trans2(img):
    return tfa.image.rotate(img,-.2,fill_mode="reflect",interpolation="bilinear")

def trans3(img):
    return tfa.image.rotate(img,.2,fill_mode="reflect",interpolation="bilinear")
    
ds1,ds2,ds3,ds4 = ds,ds.map(trans1),ds.map(trans2),ds.map(trans3)

ds = ds1.concatenate(ds2).concatenate(ds3).concatenate(ds4)

AUTOTUNE = tf.data.experimental.AUTOTUNE
ds = (
    ds
    .map(convert_to_float)
    .cache()
    .prefetch(buffer_size=AUTOTUNE)
)
# Out:
# Found 320 files belonging to 1 classes.
# 2022-11-21 01:40:00.036834: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-21 01:40:00.165089: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-21 01:40:00.165883: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-21 01:40:00.169085: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-21 01:40:00.170158: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-21 01:40:00.170903: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-21 01:40:00.171553: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-21 01:40:02.576410: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-21 01:40:02.577283: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-21 01:40:02.577971: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-21 01:40:02.578558: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
ds_a = image_dataset_from_directory(
    '../input/screwanomalies-detection/screw/test/scratch_neck',
    labels=None,
    image_size=image_size,
    interpolation='nearest',
    batch_size=batch_size,
    shuffle=True,
)
print(type(ds))

def convert_to_float(image):
    image = tf.image.convert_image_dtype(image, dtype=tf.float32)
    return image

AUTOTUNE = tf.data.experimental.AUTOTUNE
ds_a = (
    ds_a
    .map(convert_to_float)
    .cache()
    .prefetch(buffer_size=AUTOTUNE)
)
# Out:
# Found 25 files belonging to 1 classes.
# <class 'tensorflow.python.data.ops.dataset_ops.PrefetchDataset'>

# %% [markdown]
# # **Making my model**

# %%
class Sampling(layers.Layer):
    """Uses (z_mean, z_log_var) to sample z, the vector encoding a digit."""

    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

# %%
lrelu = tf.nn.selu

# %%
latent_dim = 32
a,b = image_size
shape=(a, b,3)


encoder_inputs = keras.Input(shape=shape)
x = layers.Conv2D(32, 3, activation="relu", strides=2, padding="same")(encoder_inputs)
x = layers.BatchNormalization()(x)
x = layers.Conv2D(64, 3, activation="relu", strides=2, padding="same")(x)
x = layers.BatchNormalization()(x)
x = layers.Conv2D(128, 3, activation="relu", strides=2, padding="same")(x)
x = layers.BatchNormalization()(x)
x = layers.Conv2D(256, 3, activation="relu", strides=2, padding="same")(x)
x = layers.Flatten()(x)
x = layers.Dense(160, activation="tanh")(x)
z_mean = layers.Dense(latent_dim, name="z_mean")(x)
z_log_var = layers.Dense(latent_dim, name="z_log_var")(x)
z = Sampling()([z_mean, z_log_var])
encoder = keras.Model(encoder_inputs, [z_mean, z_log_var, z], name="encoder")
encoder.summary()
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 64, 64, 32)   896         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 64, 64, 32)   128         conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 64)   18496       batch_normalization[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 64)   256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 16, 16, 128)  73856       batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 16, 16, 128)  512         conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 8, 8, 256)    295168      batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 16384)        0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 160)          2621600     flatten[0][0]
# __________________________________________________________________________________________________
# z_mean (Dense)                  (None, 32)           5152        dense[0][0]
# __________________________________________________________________________________________________
# z_log_var (Dense)               (None, 32)           5152        dense[0][0]
# __________________________________________________________________________________________________
# sampling (Sampling)             (None, 32)           0           z_mean[0][0]
#                                                                  z_log_var[0][0]
# ==================================================================================================
# Total params: 3,021,216
# Trainable params: 3,020,768
# Non-trainable params: 448
# __________________________________________________________________________________________________

# %%
latent_inputs = keras.Input(shape=(latent_dim,))
x = layers.Dense(8* 8 * 64, activation="relu")(latent_inputs)
x = layers.Reshape((8, 8, 64))(x)
x = layers.Conv2DTranspose(256, 2, activation="relu", strides=2, padding="same")(x)
x = layers.Conv2D(256, 3, activation="relu", strides=1, padding="same")(x)
x = layers.BatchNormalization()(x)
x = layers.Conv2DTranspose(128, 2, activation="relu", strides=2, padding="same")(x)
x = layers.Conv2D(128, 3, activation="relu", strides=1, padding="same")(x)
x = layers.BatchNormalization()(x)
x = layers.Conv2DTranspose(64, 2, activation="relu", strides=2, padding="same")(x)
x = layers.Conv2D(64, 3, activation="relu", strides=1, padding="same")(x)
x = layers.BatchNormalization()(x)
x = layers.Conv2DTranspose(32, 2, activation="relu", strides=2, padding="same")(x)
x = layers.Conv2D(32, 3, activation="relu", strides=1, padding="same")(x)
decoder_outputs = layers.Conv2DTranspose(3, 3, activation="sigmoid", padding="same")(x)
decoder = keras.Model(latent_inputs, decoder_outputs, name="decoder")
decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 32)]              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              135168
# _________________________________________________________________
# reshape (Reshape)            (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 16, 16, 256)       65792
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 256)       590080
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16, 16, 256)       1024
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 32, 32, 128)       131200
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 32, 32, 128)       147584
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 32, 32, 128)       512
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 64, 64, 64)        32832
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 64, 64, 64)        36928
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 64, 64, 64)        256
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, 128, 128, 32)      8224
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 128, 128, 32)      9248
# _________________________________________________________________
# conv2d_transpose_4 (Conv2DTr (None, 128, 128, 3)       867
# =================================================================
# Total params: 1,159,715
# Trainable params: 1,158,819
# Non-trainable params: 896
# _________________________________________________________________

# %%
discriminator_inputs = keras.Input(shape=shape)

x = layers.Conv2D(128, 8, activation="relu", strides=2, padding="same")(discriminator_inputs)
x = layers.MaxPool2D()(x)
x = layers.BatchNormalization()(x)
x = layers.Conv2D(64, 5, activation="relu", strides=2, padding="same")(x)
x = layers.MaxPool2D()(x)
x = layers.BatchNormalization()(x)
x = layers.Conv2D(32, 4, activation="relu", strides=2, padding="same")(x)
x = layers.Flatten()(x)
x = layers.Dense(128, activation="relu")(x)
discriminator_outputs = layers.Dense(1,activation="sigmoid")(x)
discriminator = keras.Model(discriminator_inputs, discriminator_outputs, name="discriminator")
discriminator.summary()
# Out:
# Model: "discriminator"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 128, 128, 3)]     0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 64, 64, 128)       24704
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 32, 32, 128)       0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 32, 32, 128)       512
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 16, 16, 64)        204864
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 8, 8, 64)          256
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 4, 4, 32)          32800
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               65664
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 328,929
# Trainable params: 328,545
# Non-trainable params: 384
# _________________________________________________________________

# %%
def corr_loss(z):
    coor_matrix = tfp.stats.correlation(z)
    loss = 0
    n,m = coor_matrix.shape
    for i in range(n):
        for j in range(m):
            if i!=j:
                loss+=coor_matrix[i,j]**2
    return loss

# %%
class VAE(keras.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super(VAE, self).__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = keras.metrics.Mean(
            name="reconstruction_loss"
        )
        self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")
        
        
    def call(self,x):
        z_mean, z_log_var, z = self.encoder(x)
        reconstruction = self.decoder(z)
        return z,reconstruction

    
    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
        ]

    def train_step(self, data):
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data)
            reconstruction = self.decoder(z)
            reconstruction_loss = tf.reduce_mean(
            tf.reduce_sum(keras.losses.binary_crossentropy(data, reconstruction), axis=(1, 2)))
            kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
            kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
            #coorelation_loss = corr_loss(z)
            
            total_loss = reconstruction_loss + kl_loss
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }

# %%
from keras import backend as K
class VAE_GAN(keras.Model):    

    def __init__(self, vae, discriminator, opti1=keras.optimizers.Adam(), opti2=keras.optimizers.Adam(), opti3=keras.optimizers.Adam(), **kwargs):
        super(VAE_GAN, self).__init__(**kwargs)
        
        self.encoder = vae.encoder
        self.decoder = vae.decoder
        self.discriminator = discriminator
        self.vae = vae
        
        self.vae_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = keras.metrics.Mean(name="reconstruction_loss")
        self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")
        self.correlation_loss_tracker = keras.metrics.Mean(name="cr_loss")
        self.disc_loss_tracker = keras.metrics.Mean(name="disc_loss")
        self.gen_loss_tracker = keras.metrics.Mean(name="gen_loss")
        self.disc_loss = keras.losses.BinaryCrossentropy()
        
        self.vae_optimizer = opti1
        self.gen_optimizer = opti2
        self.disc_optimizer = opti3
        
    def call(self,x):
        z_mean, z_log_var, z = self.encoder(x)
        reconstruction = self.decoder(z)
        return z,reconstruction

    @property
    def metrics(self):
        return [
            self.vae_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
            self.correlation_loss_tracker,
            self.disc_loss_tracker,
            self.gen_loss_tracker
        ]

    def train_step(self, data):        
        batch_size = K.shape(data)[0]    
        
        with tf.GradientTape() as enc_tape, tf.GradientTape() as dec_tape, tf.GradientTape() as disc_tape:
            
            z_mean, z_log_var, z = self.encoder(data)
            
            reconstruction = self.decoder(z)
            
            reconstruction_loss = tf.reduce_mean(
            tf.reduce_sum(keras.losses.binary_crossentropy(data, reconstruction), axis=(1, 2)))
            kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
            kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
            coorelation_loss = corr_loss(z)
            
            
            # GAN
            #batch_size = 12
            recon_vect = z#tf.random.normal((batch_size, latent_dim))
            contruction = self.decoder(recon_vect)
            combined_images = tf.concat([data, contruction], axis=0)
            data_l,recon_l = tf.zeros((batch_size, 1)),tf.ones((batch_size, 1))
            combined_l = tf.concat([data_l, recon_l], axis=0)
            tot_predictions = self.discriminator(combined_images)
            r_prediction = self.discriminator(contruction)

            discr_loss = self.disc_loss(combined_l,tot_predictions)
            #fake labels : 
            #gen_loss =  self.disc_loss(recon_l,r_prediction)
            gen_loss = tf.math.maximum(self.disc_loss(data_l,r_prediction) - discr_loss,.0001)
        
            #=========
            vae_loss = reconstruction_loss + kl_loss + gen_loss #+.1*coorelation_loss 

               
        grad_discr = disc_tape.gradient(discr_loss, self.discriminator.trainable_weights)
        grad_vae = enc_tape.gradient(vae_loss, self.vae.trainable_weights)
        #grad_gen = dec_tape.gradient(gen_loss, self.decoder.trainable_weights)
        
        
        #self.gen_optimizer.apply_gradients(zip(grad_gen, self.decoder.trainable_weights))
        self.disc_optimizer.apply_gradients(zip(grad_discr, self.discriminator.trainable_weights))
        self.vae_optimizer.apply_gradients(zip(grad_vae, self.vae.trainable_weights))

                                           
        self.vae_loss_tracker.update_state(vae_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        self.correlation_loss_tracker.update_state(coorelation_loss)
        self.disc_loss_tracker.update_state(discr_loss)
        self.gen_loss_tracker.update_state(gen_loss)
        
        return {
            "vae_loss": self.vae_loss_tracker.result(),
            "disc_loss": self.disc_loss_tracker.result(),
            "gen_los": self.gen_loss_tracker.result(),
        }

# %% [markdown]
# # **Training**

# %%
vae = VAE(encoder,decoder)
model = VAE_GAN(vae, discriminator)
model.compile(optimizer=keras.optimizers.Adam())

# %%
history = model.fit(ds, epochs=500,verbose=1)
# Out:
# 2022-11-21 01:40:04.954966: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/500
# 2022-11-21 01:40:21.925599: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 56/56 [==============================] - 38s 262ms/step - vae_loss: 10451.9274 - disc_loss: 0.6027 - gen_los: 0.2316
# Epoch 2/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9592.4511 - disc_loss: 0.1177 - gen_los: 2.0536
# Epoch 3/500
# 56/56 [==============================] - 4s 79ms/step - vae_loss: 9555.0921 - disc_loss: 0.0224 - gen_los: 5.2544
# Epoch 4/500
# 56/56 [==============================] - 4s 79ms/step - vae_loss: 9379.9408 - disc_loss: 0.1784 - gen_los: 4.2625
# Epoch 5/500
# 56/56 [==============================] - 4s 79ms/step - vae_loss: 9310.7197 - disc_loss: 0.0975 - gen_los: 3.8265
# Epoch 6/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9259.4323 - disc_loss: 0.3639 - gen_los: 1.4003
# Epoch 7/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9200.8805 - disc_loss: 0.5954 - gen_los: 0.9030
# Epoch 8/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9180.5256 - disc_loss: 0.4506 - gen_los: 0.8827
# Epoch 9/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9174.0412 - disc_loss: 0.3091 - gen_los: 1.2235
# Epoch 10/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9166.2045 - disc_loss: 0.1350 - gen_los: 2.4910
# Epoch 11/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9159.5995 - disc_loss: 0.2240 - gen_los: 2.9362
# Epoch 12/500
# 56/56 [==============================] - 4s 79ms/step - vae_loss: 9162.1727 - disc_loss: 0.1532 - gen_los: 3.4579
# Epoch 13/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9152.3011 - disc_loss: 0.1258 - gen_los: 3.7131
# Epoch 14/500
# 56/56 [==============================] - 4s 79ms/step - vae_loss: 9154.2361 - disc_loss: 0.1568 - gen_los: 4.1869
# Epoch 15/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 
500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9100.0602 - disc_loss: 0.4363 - gen_los: 1.4580
# Epoch 91/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9102.9911 - disc_loss: 0.4494 - gen_los: 1.3556
# Epoch 92/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9100.6469 - disc_loss: 0.4354 - gen_los: 1.4957
# Epoch 93/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9099.4624 - disc_loss: 0.4526 - gen_los: 1.2846
# Epoch 94/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9101.0508 - disc_loss: 0.4100 - gen_los: 1.5023
# Epoch 95/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9101.0457 - disc_loss: 0.4187 - gen_los: 1.6142
# Epoch 96/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9099.9585 - disc_loss: 0.4525 - gen_los: 1.3711
# Epoch 97/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9099.2924 - disc_loss: 0.4422 - gen_los: 1.4866
# Epoch 98/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9101.5410 - disc_loss: 0.4492 - gen_los: 1.3892
# Epoch 99/500
# 56/56 [==============================] - 4s 79ms/step - vae_loss: 9101.3248 - disc_loss: 0.4644 - gen_los: 1.4731
# Epoch 100/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9101.9801 - disc_loss: 0.3985 - gen_los: 1.5752
# Epoch 101/500
# 56/56 [==============================] - 4s 79ms/step - vae_loss: 9101.5562 - disc_loss: 0.4466 - gen_los: 1.3581
# Epoch 102/500
# 56/56 [==============================] - 4s 79ms/step - vae_loss: 9100.7938 - disc_loss: 0.4572 - gen_los: 1.4987
# Epoch 103/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9098.6019 - disc_loss: 0.4787 - gen_los: 1.1228
# Epoch 104/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9105.8050 - disc_loss: 0.4329 - gen_los: 1.5261
# Epoch 105/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9103.5373 - disc_loss: 0.4805 - gen_los: 1.5126
# Epoch 106/500
# 56/56 [==============================] - 4s 79ms/step - vae_loss: 9097.7082 - disc_loss: 0.4699 - gen_los: 1.3115
# Epoch 107/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9098.1669 - disc_loss: 0.4486 - gen_los: 1.4709
# Epoch 108/500
# 56/56 [==============================] - 4s 79ms/step - vae_loss: 9101.3600 - disc_loss: 0.4355 - gen_los: 1.3246
# Epoch 109/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9098.2338 - disc_loss: 0.4533 - gen_los: 1.3820
# Epoch 110/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9098.1100 - disc_loss: 0.4117 - gen_los: 1.6170
# Epoch 111/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9098.0341 - disc_loss: 0.4621 - gen_los: 1.4791
# Epoch 112/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9098.4623 - disc_loss: 0.4581 - gen_los: 1.4536
# Epoch 113/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9096.6347 - disc_loss: 0.4295 - gen_los: 1.4801
# Epoch 114/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9097.5636 - disc_loss: 0.4307 - gen_los: 1.5445
# Epoch 115/500
# 56/56 [==============================] - 5s 81ms/step - vae_loss: 9097.2009 - disc_loss: 0.4018 - gen_los: 1.8632
# Epoch 116/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9096.0378 - disc_loss: 0.3960 - gen_los: 1.7480
# Epoch 117/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9098.0383 - disc_loss: 0.3779 - gen_los: 1.6988
# Epoch 118/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9097.6640 - disc_loss: 0.3993 - gen_los: 1.7861
# Epoch 119/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9096.2162 - disc_loss: 0.3620 - gen_los: 1.9085
# Epoch 120/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9098.8816 - disc_loss: 0.3981 - gen_los: 1.9128
# Epoch 121/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9097.1036 - disc_loss: 0.4144 - gen_los: 1.7265
# Epoch 122/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9100.7302 - disc_loss: 0.4119 - gen_los: 1.7364
# Epoch 123/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9095.8535 - disc_loss: 0.4083 - gen_los: 1.7697
# Epoch 124/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9097.3178 - disc_loss: 0.3931 - gen_los: 2.0371
# Epoch 125/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9095.7356 - disc_loss: 0.3645 - gen_los: 2.0356
# Epoch 126/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9097.1884 - disc_loss: 0.4042 - gen_los: 1.8937
# Epoch 127/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9098.2812 - disc_loss: 0.4007 - gen_los: 1.7655
# Epoch 128/500
# 56/56 [==============================] - 4s 80ms/step - vae_loss: 
500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9089.6955 - disc_loss: 0.4003 - gen_los: 1.5902
# Epoch 168/500
# 56/56 [==============================] - 4s 80ms/step - vae_loss: 9089.2026 - disc_loss: 0.4489 - gen_los: 1.4555
# Epoch 169/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9089.9099 - disc_loss: 0.4469 - gen_los: 1.5533
# Epoch 170/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9091.4538 - disc_loss: 0.4316 - gen_los: 1.4825
# Epoch 171/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9093.3005 - disc_loss: 0.4419 - gen_los: 1.6969
# Epoch 172/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9093.1873 - disc_loss: 0.4340 - gen_los: 1.8003
# Epoch 173/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9094.8465 - disc_loss: 0.4238 - gen_los: 1.6085
# Epoch 174/500
# 56/56 [==============================] - 4s 79ms/step - vae_loss: 9096.9771 - disc_loss: 0.4777 - gen_los: 1.5926
# Epoch 175/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9093.0623 - disc_loss: 0.4335 - gen_los: 1.4699
# Epoch 176/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9093.0082 - disc_loss: 0.4502 - gen_los: 1.6776
# Epoch 177/500
# 56/56 [==============================] - 4s 79ms/step - vae_loss: 9090.6851 - disc_loss: 0.4486 - gen_los: 1.5444
# Epoch 178/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9089.5159 - disc_loss: 0.4733 - gen_los: 1.4983
# Epoch 179/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9090.3290 - disc_loss: 0.4757 - gen_los: 1.3666
# Epoch 180/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9089.6986 - disc_loss: 0.4788 - gen_los: 1.6697
# Epoch 181/500
# 56/56 [==============================] - 4s 79ms/step - vae_loss: 9089.5791 - disc_loss: 0.4534 - gen_los: 1.4703
# Epoch 182/500
# 56/56 [==============================] - 4s 79ms/step - vae_loss: 9091.7684 - disc_loss: 0.4577 - gen_los: 1.4848
# Epoch 183/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9094.7827 - disc_loss: 0.4150 - gen_los: 1.6823
# Epoch 184/500
# 56/56 [==============================] - 4s 79ms/step - vae_loss: 9090.7334 - disc_loss: 0.4400 - gen_los: 1.4140
# Epoch 185/500
# 56/56 [==============================] - 4s 79ms/step - vae_loss: 9092.5398 - disc_loss: 0.4148 - gen_los: 1.9444
# Epoch 186/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9090.4213 - disc_loss: 0.4543 - gen_los: 1.6694
# Epoch 187/500
# 56/56 [==============================] - 4s 79ms/step - vae_loss: 9089.7647 - disc_loss: 0.4487 - gen_los: 1.5351
# Epoch 188/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9090.5330 - disc_loss: 0.4118 - gen_los: 1.4364
# Epoch 189/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9089.9563 - disc_loss: 0.4416 - gen_los: 1.3497
# Epoch 190/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9091.6962 - disc_loss: 0.4190 - gen_los: 1.5117
# Epoch 191/500
# 56/56 [==============================] - 4s 79ms/step - vae_loss: 9089.8631 - disc_loss: 0.4986 - gen_los: 1.3355
# Epoch 192/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9090.1489 - disc_loss: 0.4429 - gen_los: 1.4541
# Epoch 193/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9091.8055 - disc_loss: 0.4304 - gen_los: 1.5328
# Epoch 194/500
# 56/56 [==============================] - 4s 80ms/step - vae_loss: 9089.4337 - disc_loss: 0.4725 - gen_los: 1.2317
# Epoch 195/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9088.5280 - disc_loss: 0.4544 - gen_los: 1.4611
# Epoch 196/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9087.1881 - disc_loss: 0.4575 - gen_los: 1.5224
# Epoch 197/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9087.3172 - disc_loss: 0.4725 - gen_los: 1.5082
# Epoch 198/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9087.1927 - disc_loss: 0.4658 - gen_los: 1.4299
# Epoch 199/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9088.3583 - disc_loss: 0.4753 - gen_los: 1.3786
# Epoch 200/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9088.9620 - disc_loss: 0.4485 - gen_los: 1.4585
# Epoch 201/500
# 56/56 [==============================] - 4s 79ms/step - vae_loss: 9088.7586 - disc_loss: 0.4586 - gen_los: 1.4776
# Epoch 202/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9087.1412 - disc_loss: 0.4762 - gen_los: 1.4389
# Epoch 203/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9085.8249 - disc_loss: 0.4928 - gen_los: 1.3978
# Epoch 204/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9086.8642 - disc_loss: 0.4826 - gen_los: 1.5690
# Epoch 205/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9085.4558 - disc_loss: 0.4304 - gen_los: 1.4038
# Epoch 206/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9086.0570 - disc_loss: 0.4501 - gen_los: 1.3808
# Epoch 207/500
# 56/56 [==============================] - 4s 79ms/step - vae_loss: 9086.2463 - disc_loss: 0.4507 - gen_los: 1.4205
# Epoch 208/500
# 56/56 [==============================] - 4s 79ms/step - vae_loss: 
500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9086.1898 - disc_loss: 0.4350 - gen_los: 1.5446
# Epoch 249/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9087.5301 - disc_loss: 0.4090 - gen_los: 1.7819
# Epoch 250/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9085.6283 - disc_loss: 0.4226 - gen_los: 1.5642
# Epoch 251/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9087.9217 - disc_loss: 0.4218 - gen_los: 1.7944
# Epoch 252/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9087.3072 - disc_loss: 0.4338 - gen_los: 1.5453
# Epoch 253/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9086.1118 - disc_loss: 0.4103 - gen_los: 1.8204
# Epoch 254/500
# 56/56 [==============================] - 4s 79ms/step - vae_loss: 9085.9910 - disc_loss: 0.4336 - gen_los: 1.8458
# Epoch 255/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9086.7983 - disc_loss: 0.4131 - gen_los: 1.8231
# Epoch 256/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9086.0566 - disc_loss: 0.4097 - gen_los: 1.6113
# Epoch 257/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9092.2418 - disc_loss: 0.4114 - gen_los: 1.8811
# Epoch 258/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9088.5349 - disc_loss: 0.4116 - gen_los: 1.8760
# Epoch 259/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9089.5482 - disc_loss: 0.4077 - gen_los: 1.8223
# Epoch 260/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9088.9571 - disc_loss: 0.4353 - gen_los: 1.7871
# Epoch 261/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9087.4930 - disc_loss: 0.4605 - gen_los: 1.5733
# Epoch 262/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9085.3238 - disc_loss: 0.4053 - gen_los: 1.6323
# Epoch 263/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9087.2969 - disc_loss: 0.4064 - gen_los: 1.8035
# Epoch 264/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9089.4987 - disc_loss: 0.3778 - gen_los: 1.8582
# Epoch 265/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9090.7087 - disc_loss: 0.4069 - gen_los: 1.8528
# Epoch 266/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9088.8713 - disc_loss: 0.4979 - gen_los: 1.3809
# Epoch 267/500
# 56/56 [==============================] - 4s 79ms/step - vae_loss: 9086.9979 - disc_loss: 0.3970 - gen_los: 1.8848
# Epoch 268/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9084.9121 - disc_loss: 0.4312 - gen_los: 1.8851
# Epoch 269/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9083.5902 - disc_loss: 0.4142 - gen_los: 1.9446
# Epoch 270/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9084.6886 - disc_loss: 0.4158 - gen_los: 1.7692
# Epoch 271/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9083.7451 - disc_loss: 0.4098 - gen_los: 1.8134
# Epoch 272/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9083.7640 - disc_loss: 0.4035 - gen_los: 1.8835
# Epoch 273/500
# 56/56 [==============================] - 4s 79ms/step - vae_loss: 9085.0310 - disc_loss: 0.4321 - gen_los: 1.7273
# Epoch 274/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9084.5305 - disc_loss: 0.4894 - gen_los: 1.7116
# Epoch 275/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9083.5503 - disc_loss: 0.4203 - gen_los: 1.7021
# Epoch 276/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9084.0228 - disc_loss: 0.3988 - gen_los: 1.9249
# Epoch 277/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9083.0398 - disc_loss: 0.4418 - gen_los: 1.5848
# Epoch 278/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9083.1678 - disc_loss: 0.4501 - gen_los: 1.7915
# Epoch 279/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9084.4966 - disc_loss: 0.4120 - gen_los: 1.7249
# Epoch 280/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9085.7762 - disc_loss: 0.3848 - gen_los: 1.9379
# Epoch 281/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9083.8929 - disc_loss: 0.3917 - gen_los: 1.9482
# Epoch 282/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9084.2608 - disc_loss: 0.4062 - gen_los: 1.8864
# Epoch 283/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9083.9475 - disc_loss: 0.3994 - gen_los: 1.8574
# Epoch 284/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9082.9991 - disc_loss: 0.4369 - gen_los: 1.6678
# Epoch 285/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9083.3050 - disc_loss: 0.4254 - gen_los: 1.8959
# Epoch 286/500
# 56/56 [==============================] - 5s 81ms/step - vae_loss: 9083.2128 - disc_loss: 0.4462 - gen_los: 1.7394
# Epoch 287/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9082.7244 - disc_loss: 0.4345 - gen_los: 1.8337
# Epoch 288/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9082.6494 - disc_loss: 0.4537 - gen_los: 1.7027
# Epoch 289/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9082.2522 - disc_loss: 0.4831 - gen_los: 1.5189
# Epoch 290/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9085.7152 - disc_loss: 0.4082 - gen_los: 1.6471
# Epoch 291/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9093.7087 - disc_loss: 0.3681 - gen_los: 2.0011
# Epoch 292/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9086.2382 - disc_loss: 0.3770 - gen_los: 2.0596
# Epoch 293/500
# 56/56 [==============================] - 4s 79ms/step - vae_loss: 9093.1698 - disc_loss: 0.4374 - gen_los: 1.9743
# Epoch 294/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9085.0601 - disc_loss: 0.3970 - gen_los: 1.6174
# Epoch 295/500
# 56/56 [==============================] - 4s 79ms/step - vae_loss: 9092.2206 - disc_loss: 0.4032 - gen_los: 1.8491
# Epoch 296/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9084.7110 - disc_loss: 0.4431 - gen_los: 1.7936
# Epoch 297/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9088.3540 - disc_loss: 0.4015 - gen_los: 1.9547
# Epoch 298/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9084.6207 - disc_loss: 0.4286 - gen_los: 1.5040
# Epoch 299/500
# 56/56 [==============================] - 4s 79ms/step - vae_loss: 9085.3904 - disc_loss: 0.3892 - gen_los: 2.0346
# Epoch 300/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9085.7329 - disc_loss: 0.4594 - gen_los: 1.8859
# Epoch 301/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9084.1630 - disc_loss: 0.3940 - gen_los: 1.9321
# Epoch 302/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9084.4184 - disc_loss: 0.3475 - gen_los: 2.3274
# Epoch 303/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9083.2124 - disc_loss: 0.3799 - gen_los: 1.8982
# Epoch 304/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9083.3425 - disc_loss: 0.3948 - gen_los: 1.8949
# Epoch 305/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9084.9566 - disc_loss: 0.3859 - gen_los: 2.1929
# Epoch 306/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9083.7931 - disc_loss: 0.3456 - gen_los: 2.1190
# Epoch 307/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9083.7666 - disc_loss: 0.4098 - gen_los: 1.6700
# Epoch 308/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9086.2226 - disc_loss: 0.3273 - gen_los: 2.7199
# Epoch 309/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9085.6768 - disc_loss: 0.3644 - gen_los: 2.3555
# Epoch 310/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9087.2201 - disc_loss: 0.3623 - gen_los: 2.2218
# Epoch 311/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9095.7307 - disc_loss: 0.2867 - gen_los: 2.6461
# Epoch 312/500
# 56/56 [==============================] - 4s 79ms/step - vae_loss: 9098.9874 - disc_loss: 0.3336 - gen_los: 2.8110
# Epoch 313/500
# 56/56 [==============================] - 4s 79ms/step - vae_loss: 9088.0043 - disc_loss: 0.3359 - gen_los: 2.7771
# Epoch 314/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9092.5764 - disc_loss: 0.3742 - gen_los: 2.4386
# Epoch 315/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9097.4867 - disc_loss: 0.3612 - gen_los: 2.6018
# Epoch 316/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9092.5551 - disc_loss: 0.3396 - gen_los: 2.3987
# Epoch 317/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9095.1564 - disc_loss: 0.3042 - gen_los: 2.7058
# Epoch 318/500
# 56/56 [==============================] - 4s 80ms/step - vae_loss: 9095.7463 - disc_loss: 0.3077 - gen_los: 2.5548
# Epoch 319/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9091.0653 - disc_loss: 0.3129 - gen_los: 2.7264
# Epoch 320/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9089.6188 - disc_loss: 0.3068 - gen_los: 3.1869
# Epoch 321/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9088.1278 - disc_loss: 0.3698 - gen_los: 2.4478 2s - vae_los
# Epoch 322/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9086.1753 - disc_loss: 0.3584 - gen_los: 2.5532
# Epoch 323/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9084.8282 - disc_loss: 0.3275 - gen_los: 2.3668
# Epoch 324/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9085.8466 - disc_loss: 0.3566 - gen_los: 2.5778
# Epoch 325/500
# 56/56 [==============================] - 4s 80ms/step - vae_loss: 9086.6125 - disc_loss: 0.3364 - gen_los: 2.4665
# Epoch 326/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9084.6646 - disc_loss: 0.3259 - gen_los: 2.7942
# Epoch 327/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9085.0293 - disc_loss: 0.3279 - gen_los: 2.7592
# Epoch 328/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9084.9911 - disc_loss: 0.3372 - gen_los: 2.5446
# Epoch 329/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9083.8791 - disc_loss: 0.3335 - gen_los: 2.3351
# Epoch 330/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9084.0826 - disc_loss: 0.3037 - gen_los: 2.4288
# Epoch 331/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9084.1015 - disc_loss: 0.3229 - gen_los: 2.5162
# Epoch 332/500
# 56/56 [==============================] - 4s 79ms/step - vae_loss: 9083.9375 - disc_loss: 0.3199 - gen_los: 2.5570
# Epoch 333/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9084.0376 - disc_loss: 0.3155 - gen_los: 2.7301
# Epoch 334/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9083.6454 - disc_loss: 0.2890 - gen_los: 2.8188
# Epoch 335/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9083.8373 - disc_loss: 0.3011 - gen_los: 2.6194
# Epoch 336/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9083.6759 - disc_loss: 0.4202 - gen_los: 2.7948
# Epoch 337/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9082.5303 - disc_loss: 0.3786 - gen_los: 2.0676
# Epoch 338/500
# 56/56 [==============================] - 4s 79ms/step - vae_loss: 9083.0780 - disc_loss: 0.3146 - gen_los: 2.4473
# Epoch 339/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9083.4529 - disc_loss: 0.2767 - gen_los: 2.9346
# Epoch 340/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9083.5161 - disc_loss: 0.3003 - gen_los: 2.7066
# Epoch 341/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9083.5103 - disc_loss: 0.3016 - gen_los: 2.7946
# Epoch 342/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9083.9276 - disc_loss: 0.3054 - gen_los: 2.7267
# Epoch 343/500
# 56/56 [==============================] - 4s 79ms/step - vae_loss: 9083.6909 - disc_loss: 0.3466 - gen_los: 2.6402
# Epoch 344/500
# 56/56 [==============================] - 4s 79ms/step - vae_loss: 9083.3943 - disc_loss: 0.3031 - gen_los: 2.7309
# Epoch 345/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9083.1971 - disc_loss: 0.3098 - gen_los: 2.7712
# Epoch 346/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9084.0330 - disc_loss: 0.2829 - gen_los: 2.8496
# Epoch 347/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9083.8493 - disc_loss: 0.2867 - gen_los: 2.8695
# Epoch 348/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9085.5377 - disc_loss: 0.2776 - gen_los: 3.0244
# Epoch 349/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9084.6143 - disc_loss: 0.2797 - gen_los: 3.1307
# Epoch 350/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9084.8867 - disc_loss: 0.2577 - gen_los: 2.9526
# Epoch 351/500
# 56/56 [==============================] - 4s 79ms/step - vae_loss: 9084.8639 - disc_loss: 0.2800 - gen_los: 3.1687
# Epoch 352/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9084.7219 - disc_loss: 0.3368 - gen_los: 3.2249
# Epoch 353/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9084.9111 - disc_loss: 0.3563 - gen_los: 3.0080
# Epoch 354/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9084.5907 - disc_loss: 0.3278 - gen_los: 2.4309
# Epoch 355/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9091.0097 - disc_loss: 0.3013 - gen_los: 2.7172
# Epoch 356/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9095.8576 - disc_loss: 0.2551 - gen_los: 3.2859
# Epoch 357/500
# 56/56 [==============================] - 5s 80ms/step - vae_loss: 9095.0929 - disc_loss: 0.2437 - gen_los: 3.2875
# Epoch 358/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9090.1592 - disc_loss: 0.3347 - gen_los: 2.8347
# Epoch 359/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9090.1285 - disc_loss: 0.3137 - gen_los: 2.8572
# Epoch 360/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9093.7036 - disc_loss: 0.3530 - gen_los: 2.7912
# Epoch 361/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9084.5759 - disc_loss: 0.3103 - gen_los: 2.6631
# Epoch 362/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9083.1669 - disc_loss: 0.3502 - gen_los: 2.8093
# Epoch 363/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9083.8790 - disc_loss: 0.3072 - gen_los: 2.6054
# Epoch 364/500
# 56/56 [==============================] - 4s 79ms/step - vae_loss: 9084.6898 - disc_loss: 0.2842 - gen_los: 2.7977
# Epoch 365/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9083.8984 - disc_loss: 0.2891 - gen_los: 2.8639
# Epoch 366/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9083.5910 - disc_loss: 0.3711 - gen_los: 2.6670
# Epoch 367/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9084.3312 - disc_loss: 0.3719 - gen_los: 2.7441
# Epoch 368/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9082.0995 - disc_loss: 0.3367 - gen_los: 2.5464
# Epoch 369/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9082.5104 - disc_loss: 0.3191 - gen_los: 2.7956
# Epoch 370/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9082.6554 - disc_loss: 0.3268 - gen_los: 2.7500
# Epoch 371/500
# 56/56 [==============================] - 4s 80ms/step - vae_loss: 9083.0211 - disc_loss: 0.2901 - gen_los: 3.0063
# Epoch 372/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9082.3805 - disc_loss: 0.3074 - gen_los: 2.4762
# Epoch 373/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9083.1578 - disc_loss: 0.3382 - gen_los: 2.4491
# Epoch 374/500
# ...
# Epoch 376/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9085.3157 - disc_loss: 0.2388 - gen_los: 3.0425
# Epoch 377/500
# 56/56 [==============================] - 4s 80ms/step - vae_loss: 9088.3922 - disc_loss: 0.2305 - gen_los: 3.3299
# Epoch 378/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9100.6765 - disc_loss: 0.2223 - gen_los: 3.8368
# Epoch 379/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9097.0817 - disc_loss: 0.2563 - gen_los: 3.4418
# Epoch 380/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9095.1319 - disc_loss: 0.2503 - gen_los: 3.7052
# Epoch 381/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9091.0682 - disc_loss: 0.3634 - gen_los: 3.2060
# Epoch 382/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9089.9689 - disc_loss: 0.3073 - gen_los: 3.0589
# Epoch 383/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9090.7678 - disc_loss: 0.3188 - gen_los: 3.0699
# Epoch 384/500
# 56/56 [==============================] - 4s 79ms/step - vae_loss: 9097.2993 - disc_loss: 0.3688 - gen_los: 3.0553
# Epoch 385/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9087.0141 - disc_loss: 0.2698 - gen_los: 2.7687
# Epoch 386/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9090.5130 - disc_loss: 0.3000 - gen_los: 3.2048
# Epoch 387/500
# 56/56 [==============================] - 4s 79ms/step - vae_loss: 9087.7566 - disc_loss: 0.3084 - gen_los: 2.6332
# Epoch 388/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9087.2227 - disc_loss: 0.2682 - gen_los: 3.1003
# Epoch 389/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9088.6775 - disc_loss: 0.3124 - gen_los: 3.3419
# Epoch 390/500
# 56/56 [==============================] - 4s 79ms/step - vae_loss: 9087.8795 - disc_loss: 0.2573 - gen_los: 3.2222
# Epoch 391/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9086.5623 - disc_loss: 0.2493 - gen_los: 3.3097
# Epoch 392/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9085.7622 - disc_loss: 0.2491 - gen_los: 4.1676
# Epoch 393/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9084.5771 - disc_loss: 0.2418 - gen_los: 3.6923
# Epoch 394/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9084.9167 - disc_loss: 0.2274 - gen_los: 3.9630
# Epoch 395/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9084.5678 - disc_loss: 0.2971 - gen_los: 3.5470
# Epoch 396/500
# 56/56 [==============================] - 4s 79ms/step - vae_loss: 9083.6275 - disc_loss: 0.2883 - gen_los: 3.6273
# Epoch 397/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9083.9456 - disc_loss: 0.2664 - gen_los: 3.7918
# Epoch 398/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9084.2448 - disc_loss: 0.3298 - gen_los: 3.4272
# Epoch 399/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9083.7127 - disc_loss: 0.2997 - gen_los: 3.3917
# Epoch 400/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9083.7217 - disc_loss: 0.2788 - gen_los: 3.3355
# Epoch 401/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9083.7753 - disc_loss: 0.2566 - gen_los: 3.5000
# Epoch 402/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9083.9388 - disc_loss: 0.2184 - gen_los: 3.6635
# Epoch 403/500
# 56/56 [==============================] - 4s 80ms/step - vae_loss: 9084.3361 - disc_loss: 0.2369 - gen_los: 3.7148
# Epoch 404/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9084.4376 - disc_loss: 0.2365 - gen_los: 3.9230
# Epoch 405/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9084.1182 - disc_loss: 0.2643 - gen_los: 3.6583
# Epoch 406/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9084.4292 - disc_loss: 0.2649 - gen_los: 3.7483
# Epoch 407/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9083.6395 - disc_loss: 0.3217 - gen_los: 3.5348
# Epoch 408/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9083.8525 - disc_loss: 0.3639 - gen_los: 3.5741
# Epoch 409/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9083.7787 - disc_loss: 0.2623 - gen_los: 3.3976
# Epoch 410/500
# 56/56 [==============================] - 5s 81ms/step - vae_loss: 9083.1474 - disc_loss: 0.2665 - gen_los: 3.5008
# Epoch 411/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9083.9158 - disc_loss: 0.2351 - gen_los: 3.6140
# Epoch 412/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9085.0808 - disc_loss: 0.2275 - gen_los: 4.1275
# Epoch 413/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9083.8754 - disc_loss: 0.2726 - gen_los: 3.7515
# Epoch 414/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9084.0847 - disc_loss: 0.2561 - gen_los: 3.8049
# Epoch 415/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9083.8818 - disc_loss: 0.2210 - gen_los: 3.6019
# Epoch 416/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9084.2731 - disc_loss: 0.2224 - gen_los: 3.8295
# Epoch 417/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9084.3403 - disc_loss: 0.2593 - gen_los: 3.9840
# Epoch 418/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9084.0844 - disc_loss: 0.2413 - gen_los: 4.0709
# Epoch 419/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9084.9005 - disc_loss: 0.2434 - gen_los: 3.7325
# Epoch 420/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9085.3306 - disc_loss: 0.2328 - gen_los: 3.6033
# Epoch 421/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9085.2713 - disc_loss: 0.2869 - gen_los: 3.7895
# Epoch 422/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9086.6925 - disc_loss: 0.2147 - gen_los: 3.6722
# Epoch 423/500
# 56/56 [==============================] - 4s 79ms/step - vae_loss: 9085.8037 - disc_loss: 0.2391 - gen_los: 4.0931
# Epoch 424/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9085.1764 - disc_loss: 0.2746 - gen_los: 3.7470
# Epoch 425/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9085.2421 - disc_loss: 0.3266 - gen_los: 3.3204
# Epoch 426/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9084.4054 - disc_loss: 0.2595 - gen_los: 3.6042
# Epoch 427/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9084.6926 - disc_loss: 0.2566 - gen_los: 3.3967
# Epoch 428/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9087.7576 - disc_loss: 0.2498 - gen_los: 4.0275
# Epoch 429/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9088.5855 - disc_loss: 0.2872 - gen_los: 3.1915
# Epoch 430/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9098.4234 - disc_loss: 0.2795 - gen_los: 3.8074
# Epoch 431/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9091.4259 - disc_loss: 0.2243 - gen_los: 4.0008
# Epoch 432/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9088.9390 - disc_loss: 0.2254 - gen_los: 3.9458
# Epoch 433/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9090.0330 - disc_loss: 0.2444 - gen_los: 4.1337
# Epoch 434/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9095.4824 - disc_loss: 0.2515 - gen_los: 4.1418
# Epoch 435/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9099.0179 - disc_loss: 0.2070 - gen_los: 4.5185
# Epoch 436/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9090.4819 - disc_loss: 0.1927 - gen_los: 4.2298
# Epoch 437/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9090.8812 - disc_loss: 0.2184 - gen_los: 4.3435
# Epoch 438/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9089.3923 - disc_loss: 0.2163 - gen_los: 4.0808
# Epoch 439/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9087.8586 - disc_loss: 0.1935 - gen_los: 4.1539
# Epoch 440/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9086.8911 - disc_loss: 0.2342 - gen_los: 4.2113
# Epoch 441/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9087.2003 - disc_loss: 0.2182 - gen_los: 3.8710
# Epoch 442/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9086.1993 - disc_loss: 0.1960 - gen_los: 4.1855
# Epoch 443/500
# 56/56 [==============================] - 4s 79ms/step - vae_loss: 9087.0655 - disc_loss: 0.2085 - gen_los: 4.5861
# Epoch 444/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9087.1695 - disc_loss: 0.2585 - gen_los: 3.6854
# Epoch 445/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9085.8091 - disc_loss: 0.2261 - gen_los: 3.8953
# Epoch 446/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9086.2962 - disc_loss: 0.2666 - gen_los: 3.9323
# Epoch 447/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9085.6695 - disc_loss: 0.2829 - gen_los: 3.8239
# Epoch 448/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9086.1991 - disc_loss: 0.2255 - gen_los: 3.6954
# Epoch 449/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9086.6018 - disc_loss: 0.2316 - gen_los: 3.9990
# Epoch 450/500
# 56/56 [==============================] - 4s 80ms/step - vae_loss: 9086.9471 - disc_loss: 0.2289 - gen_los: 3.6511
# Epoch 451/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9087.8423 - disc_loss: 0.2626 - gen_los: 3.6075
# Epoch 452/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9093.0285 - disc_loss: 0.2516 - gen_los: 3.8673
# Epoch 453/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9098.3036 - disc_loss: 0.1777 - gen_los: 4.8343
# Epoch 454/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9088.5971 - disc_loss: 0.1472 - gen_los: 4.6023
# Epoch 455/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9089.1652 - disc_loss: 0.1749 - gen_los: 4.1343
# Epoch 456/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9089.3499 - disc_loss: 0.2015 - gen_los: 3.8691
# Epoch 457/500
# 56/56 [==============================] - 4s 79ms/step - vae_loss: 9089.3478 - disc_loss: 0.1802 - gen_los: 4.4323
# Epoch 458/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9088.1656 - disc_loss: 0.1730 - gen_los: 4.4346
# Epoch 459/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9087.4686 - disc_loss: 0.1994 - gen_los: 4.5359
# Epoch 460/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9087.8450 - disc_loss: 0.1638 - gen_los: 4.7155
# Epoch 461/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9087.5637 - disc_loss: 0.1815 - gen_los: 4.4393
# Epoch 462/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9089.3077 - disc_loss: 0.1926 - gen_los: 4.3957
# Epoch 463/500
# 56/56 [==============================] - 4s 79ms/step - vae_loss: 9088.9548 - disc_loss: 0.1892 - gen_los: 4.5025
# Epoch 464/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9089.2300 - disc_loss: 0.2510 - gen_los: 4.7372
# Epoch 465/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9088.5027 - disc_loss: 0.2476 - gen_los: 4.1353
# Epoch 466/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9087.6726 - disc_loss: 0.2390 - gen_los: 3.6990
# Epoch 467/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9086.7012 - disc_loss: 0.2358 - gen_los: 3.7969
# Epoch 468/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9086.3027 - disc_loss: 0.2530 - gen_los: 3.6962
# Epoch 469/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9086.3590 - disc_loss: 0.2359 - gen_los: 3.9534
# Epoch 470/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9085.8601 - disc_loss: 0.2768 - gen_los: 4.0905
# Epoch 471/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9085.8215 - disc_loss: 0.1822 - gen_los: 4.3895
# Epoch 472/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9084.9604 - disc_loss: 0.2232 - gen_los: 4.0774
# Epoch 473/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9085.1190 - disc_loss: 0.2286 - gen_los: 4.0374
# Epoch 474/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9085.9911 - disc_loss: 0.2260 - gen_los: 4.1002
# Epoch 475/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9085.9743 - disc_loss: 0.1994 - gen_los: 4.0203
# Epoch 476/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9087.0160 - disc_loss: 0.1671 - gen_los: 4.6692
# Epoch 477/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9086.2269 - disc_loss: 0.1792 - gen_los: 4.2758
# Epoch 478/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9086.8612 - disc_loss: 0.1979 - gen_los: 4.4457
# Epoch 479/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9086.3939 - disc_loss: 0.2537 - gen_los: 4.3762
# Epoch 480/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9087.6798 - disc_loss: 0.2094 - gen_los: 4.1388
# Epoch 481/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9088.2836 - disc_loss: 0.2172 - gen_los: 4.0818
# Epoch 482/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9091.7180 - disc_loss: 0.1798 - gen_los: 4.4839
# Epoch 483/500
# 56/56 [==============================] - 4s 79ms/step - vae_loss: 9097.8019 - disc_loss: 0.1450 - gen_los: 4.2714
# Epoch 484/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9090.0828 - disc_loss: 0.1369 - gen_los: 4.8759
# Epoch 485/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9089.8238 - disc_loss: 0.2042 - gen_los: 4.8749
# Epoch 486/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9088.4335 - disc_loss: 0.1790 - gen_los: 4.7762
# Epoch 487/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9090.5023 - disc_loss: 0.1466 - gen_los: 5.2079
# Epoch 488/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9091.2058 - disc_loss: 0.1316 - gen_los: 4.6788
# Epoch 489/500
# 56/56 [==============================] - 4s 80ms/step - vae_loss: 9094.5136 - disc_loss: 0.1486 - gen_los: 5.1473
# Epoch 490/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9099.5762 - disc_loss: 0.1356 - gen_los: 5.0638
# Epoch 491/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9104.5207 - disc_loss: 0.1318 - gen_los: 5.7330
# Epoch 492/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9099.5721 - disc_loss: 0.1267 - gen_los: 5.6860
# Epoch 493/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9096.3851 - disc_loss: 0.1183 - gen_los: 5.5878
# Epoch 494/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9097.2857 - disc_loss: 0.1475 - gen_los: 5.3414
# Epoch 495/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9095.0362 - disc_loss: 0.1441 - gen_los: 5.5679
# Epoch 496/500
# 56/56 [==============================] - 4s 80ms/step - vae_loss: 9094.8933 - disc_loss: 0.1718 - gen_los: 5.2765
# Epoch 497/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9093.0458 - disc_loss: 0.1664 - gen_los: 5.6479
# Epoch 498/500
# 56/56 [==============================] - 4s 78ms/step - vae_loss: 9091.4186 - disc_loss: 0.1565 - gen_los: 5.1571
# Epoch 499/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9090.9924 - disc_loss: 0.1322 - gen_los: 5.2753
# Epoch 500/500
# 56/56 [==============================] - 4s 77ms/step - vae_loss: 9090.8817 - disc_loss: 0.1210 - gen_los: 5.3302

# %% [markdown]
# #  **Results Analyse**

# %%
import pandas as pd
history_frame = pd.DataFrame(history.history)
history_frame.loc[:, ['vae_loss']].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Latent space

# %%
_ ,digit_size = image_size
scale = 1
def plot_latent_space(vae, n=8, figsize=15):
    # display a n*n 2D manifold of digits
    figure = np.zeros((digit_size * n, digit_size * n,3))
    # linearly spaced coordinates corresponding to the 2D plot
    # of digit classes in the latent space
    grid_x = np.linspace(-scale, scale, n)
    grid_y = np.linspace(-scale, scale, n)[::-1]

    for i, yi in enumerate(grid_y):
        for j, xi in enumerate(grid_x):
            z_sample = np.array([[2*random.random()-1 for i in range(latent_dim)]])
            x_decoded = vae.decoder.predict(z_sample)
            digit = x_decoded[0].reshape(digit_size, digit_size,3)
            figure[
                i * digit_size : (i + 1) * digit_size,
                j * digit_size : (j + 1) * digit_size,
            ] = digit

    plt.figure(figsize=(figsize, figsize))
    start_range = digit_size // 2
    end_range = n * digit_size + start_range
    pixel_range = np.arange(start_range, end_range, digit_size)
    sample_range_x = np.round(grid_x, 1)
    sample_range_y = np.round(grid_y, 1)
    plt.xticks(pixel_range, sample_range_x)
    plt.yticks(pixel_range, sample_range_y)
    plt.xlabel("z[0]")
    plt.ylabel("z[1]")
    plt.imshow(figure)
    plt.show()


plot_latent_space(model)

# %% [markdown]
# # On training set

# %%
digit_size, _ = image_size
n = 4
figure = np.zeros((digit_size*3, digit_size * n,3))
img = list(ds)[0]

for i in range(n):
    _,b_img = model(img)
    a = list(b_img)[i]
    figure[
                 0*digit_size :  digit_size,
                i * digit_size :  (i+1)* digit_size,
            ] = a
    figure[
                 1*digit_size :  2*digit_size,
                i * digit_size :  (i+1)* digit_size,
            ] = list(img)[i]
    
    figure[
                 2*digit_size :  3*digit_size,
                i * digit_size :  (i+1)* digit_size,
            ] = (a-list(img)[i])*10


figsize = 5   
plt.figure(figsize=(figsize*n, figsize*3))
plt.imshow(figure)
plt.show()

# %% [markdown]
# # On test set

# %%
n = 2
figure = np.zeros((digit_size*3, digit_size * n,3))
img = list(ds_a)[0]
for i in range(n):
    _,b_img = model(img)
    a = list(b_img)[i]
    figure[
                 0*digit_size :  digit_size,
                i * digit_size :  (i+1)* digit_size,
            ] = a
    figure[
                 1*digit_size :  2*digit_size,
                i * digit_size :  (i+1)* digit_size,
            ] = list(img)[i]
    
    figure[
                 2*digit_size :  3*digit_size,
                i * digit_size :  (i+1)* digit_size,
            ] = (a-list(img)[i])*10

figsize = 10  
plt.figure(figsize=(figsize*n, figsize*3))
plt.imshow(figure)
plt.show()
