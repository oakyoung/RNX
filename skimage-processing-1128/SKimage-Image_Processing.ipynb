# %% [markdown]
# # Make images come alive with scikit-image

# %%
pip install Pillow
# Out:
# Requirement already satisfied: Pillow in c:\users\muham\anaconda3\lib\site-packages (8.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import PIL
print('Pillow Version:', PIL.__version__)
# Out:
# Pillow Version: 8.1.0

# %%
import PIL
# load and show an image with Pillow
from PIL import Image
# load the image
image = Image.open(r'C:\Users\muham\Downloads\download (7).jfif')
# summarize some details about the image
print(image.format)
print(image.mode)
print(image.size)
# show the image
image.show()
# Out:
# JPEG
# RGB
# (275, 183)

# %%
from matplotlib import pyplot
# display the array of pixels as an image
pyplot.imshow(image)
pyplot.show()

# %%
import matplotlib.pyplot as plt

from skimage import data
from skimage.color import rgb2gray

original = data.astronaut()
grayscale = rgb2gray(original)

fig, axes = plt.subplots(1, 2, figsize=(8, 4))
ax = axes.ravel()

ax[0].imshow(original)
ax[0].set_title("Original")
ax[1].imshow(grayscale, cmap=plt.cm.gray)
ax[1].set_title("Grayscale")

fig.tight_layout()
plt.show()

# %%
# create a Show_image FUnction
def show_img(image, title='Image', cmap_type='gray'):
    plt.imshow(image, cmap=cmap_type)
    plt.title('Show your image')
    plt.axis('off')
    plt.show()

# %%
# Import the modules from skimage
from skimage import data, color

# Load the rocket image
rocket = data.rocket()

# Convert the image to grayscale
gray_scaled_rocket = color.rgb2gray(rocket) 

# Show the original image
show_img(rocket, 'Original RGB image')

# Show the grayscale image
show_img(gray_scaled_rocket, 'Grayscale image')

# %% [markdown]
# # Numpy for images

# %%
# images as nd arrays
imag = plt.imread(r'C:\Users\muham\Downloads\download (7).jfif')
type(imag)
# Out:
# numpy.ndarray

# %% [markdown]
# # Colors with Numpy

# %%
# obtaining with the 
# obtaining red values of an image
import numpy as np
# Obtain the red channel
#red_channel = image[:, :, 0]

# Plot the red histogram with bins in a range of 256
#plt.hist(red_channel.ravel(), bins=256)

# Set title and show
#plt.title('Red Histogram')
#plt.show()

# %%
# flip the image vertically
gr = Image.open(r'C:\Users\muham\Downloads\download (7).jfif')
v_f =np.flipud(gr)
show_img(v_f, 'Vertically Flipped Image')

# %%
# Flip the image vertically
seville_vertical_flip = np.flipud(gr)

# Flip the previous image horizontally
seville_horizontal_flip = np.fliplr(gr)

# %%
show_img(seville_horizontal_flip, 'Seville')

# %%
show_img(seville_vertical_flip, 'none')

# %% [markdown]
# # Getting started with thresholding

# %%
# obtain the optimal threholding value
thresh = 127
image = Image.open(r'C:\Users\muham\Downloads\france-in-pictures-beautiful-places-to-photograph-eiffel-tower (1).png')
image = np.array(image)
# apply to image
binary = image > thresh

# %%
# Import the otsu threshold function
from skimage.color import rgb2gray
from skimage.filters import threshold_otsu

# Make the image grayscale using rgb2gray
image_gray = color.rgb2gray(image)

# Obtain the optimal threshold value with otsu
thresh = threshold_otsu(image_gray)

# Apply thresholding to the image
binary = image_gray > thresh

# Show the image
show_img(binary, 'Binary image')

# %%
# Import the local threshold function
from skimage.filters import threshold_local

# Set the block size to 35
##block_size = 35

# Obtain the optimal local thresholding
##local_thresh = threshold_local(page_image, block_size, offset=10)

# Obtain the binary image by applying local thresholding
##binary_local = page_image > local_thresh

# Show the binary image
##show_img(binary_local, 'Local thresholding')

# %%
# Import the try all function
from skimage.filters import try_all_threshold
image = Image.open(r'C:\Users\muham\Downloads\france-in-pictures-beautiful-places-to-photograph-eiffel-tower (1).png')
image = np.array(image)
# Import the rgb to gray convertor function 
from skimage.color import rgb2gray

# Turn the fruits_image to grayscale
grayscale = rgb2gray(image)

# Use the try all method on the resulting grayscale image
fig, ax = try_all_threshold(grayscale, verbose=False)

# Show the resulting plots
plt.show()

# %%
# Import the try all function
from skimage.filters import try_all_threshold

# Import the rgb to gray convertor function 
from skimage.color import rgb2gray

# Turn the fruits_image to grayscale
grayscale = rgb2gray(image)

# Use the try all method on the resulting grayscale image
fig, ax = try_all_threshold(grayscale, verbose=False)

# Show the resulting plots
plt.show()

# %% [markdown]
# # Jump into filtering

# %%
def plot_comparison(original, filtered, title_filtered):
  fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(8, 6), sharex=True, sharey=True)
  ax1.imshow(original, cmap=plt.cm.gray) 
  ax1.set_title('original') 
  ax1.axis('off')
  ax2.imshow(filtered, cmap=plt.cm.gray) 
  ax2.set_title(title_filtered) 
  ax2.axis('off')

# %%
# Edge detection- Sobel
from skimage.filters import sobel
# Apply edge detection algos
edge_sobel = sobel(image)
# Show Image comparison
plot_comparison(image, edge_sobel, 'Edge with Sobel')

# %%
# Import the color module
from skimage import color

# Import the filters module and sobel function
from skimage.filters import sobel

# Make the image grayscale
soaps_image_gray = color.rgb2gray(image)

# Apply edge detection filter
edge_sobel = sobel(image)

# Show original and resulting image to compare
show_img(soaps_image_gray, "Original")
show_img(edge_sobel, "Edges with Sobel")

# %%
# Import Gaussian filter 
from skimage.filters import gaussian
image = Image.open(r'C:\Users\muham\Downloads\observation-urban-building-business-steel_1127-2397.jpg')
image = np.array(image)
# Apply filter
gaussian_image = gaussian(image, multichannel=True)

# Show original and resulting image to compare
show_img(image, "Original")
show_img(gaussian_image, "Reduced sharpness Gaussian")

# %% [markdown]
# # Contrast enhancement

# %%
from skimage import exposure as ex
# obtain the equalized image
img_eq = ex.equalize_hist(image)
# show Original and result
show_img(image, 'Original')
show_img(img_eq, 'Histogram equalized')

# %%
# Import the required module
from skimage import exposure
chest_xray_image = Image.open(r'C:\Users\muham\Downloads\chestray.jpg')
chest_xray_image = np.array(chest_xray_image)
# Show original x-ray image and its histogram
show_img(chest_xray_image, 'Original x-ray')

plt.title('Histogram of image')
plt.hist(chest_xray_image.ravel(), bins=256)
plt.show()

# %%
# Import the required module
from skimage import exposure

# Show original x-ray image and its histogram
show_img(chest_xray_image, 'Original x-ray')

plt.title('Histogram of image')
plt.hist(chest_xray_image.ravel(), bins=256)
plt.show()

# Use histogram equalization to improve the contrast
xray_image_eq =  exposure.equalize_hist(chest_xray_image)

# Show the resulting image and its stats
show_img(xray_image_eq, 'Resulted image')
plt.title('Histogram of resulting image')
plt.hist(xray_image_eq.ravel(), bins=256)
plt.show()

# %%
# Import the required module
from skimage import exposure
image_aerial = Image.open(r'C:\Users\muham\Downloads\Aerial_Survey_in_Action.jpg')
image_aerial = np.array(image_aerial)
# Use histogram equalization to improve the contrast
image_eq1 =  exposure.equalize_hist(image_aerial)

# Show the original and resulting image
show_img(image_aerial, 'Original')
show_img(image_eq1, 'Resulting image')

# %%
# Import the necessary modules
from skimage import data, exposure

# Load the image
original_image = data.coffee()

# Apply the adaptive equalization on the original image
adapthist_eq_image = exposure.equalize_adapthist(original_image, clip_limit=0.03)

# Compare the original image to the equalized
show_img(original_image)
show_img(adapthist_eq_image, '#ImageProcessingDatacamp')

# %% [markdown]
# # Rotating

# %%
# rotating image clockwise
#90 degrees
from skimage.transform import rotate as rt
imge_rotate = rt(original_image, -90)
show_img(imge_rotate, 'Rotated image')

# %% [markdown]
# # Rescaling

# %%
from skimage.transform import rescale
img_rs = rescale(image, 1/4, anti_aliasing=True, multichannel=True)
show_img(img_rs,'Rescaled')

# %% [markdown]
# # Resizing Image

# %%
from skimage.transform import resize
# set proportional height so its 4 times its size
height = image.shape[0] /4
width = image.shape[1] /4
# converted to int as it cannot read in floats
width = int(width)
height = int(height)
image_resize = resize(image, (height, width), anti_aliasing=True)
show_img(image_resize, 'Resized')

# %% [markdown]
# # Enlarging Images

# %%
# Import the data module
from skimage import data

# Load the image from data
rocket_image = data.rocket()

# Enlarge the image so it is 3 times bigger
enlarged_rocket_image = rescale(rocket_image, 0.5, anti_aliasing=True, multichannel=True)

# Show original and resulting image
show_img(rocket_image)
show_img(enlarged_rocket_image, "0.5 times enlarged image")

# %%
# Import the module and function
from skimage.transform import resize

# Set proportional height and width so it is half its size
height = int(image.shape[0] / 2.0)
width = int(image.shape[1] / 2.0)
# Resize using the calculated proportional height and width
image_resized = resize(image, (height, width),
                       anti_aliasing=True)

# Show the original and rotated image
show_img(image, 'Original')
show_img(image_resized, 'Resized image')

# %% [markdown]
# # Morphology: Filtering, operations
# # Shapes and erosion in Sckit images

# %%
original_image.shape

# %%
from skimage import morphology
square = morphology.square(4)
rectangle = morphology.rectangle(4,2)
selem = morphology.rectangle(417, 626) # KNOWN AS EROSION START
# OBTAIN EROSED IMAGE WITH BINARY EROSION
#ERODED_IMAGE = morphology.binary_erosion(image, selem=selem)
# plot_comparison(image, ERODED_IMAGE,'Erosion')

# %%
# Obtain dilated image
dil_img = morphology.binary_dilation(image)

# %%
#ERODED_IMAGE = morphology.binary_erosion(dil_img, selem=selem)

# %%
# See results
#show_image(upper_r_image, 'Original')
#show_image(eroded_image_shape, 'Eroded image')

# %% [markdown]
# # Image restoration

# %%
def get_mask(image):
    ''' Creates mask with three defect regions '''
    mask = np.zeros(image.shape[:-1])
    mask[101:106, 0:240] = 1
    mask[152:154, 0:60] = 1
    mask[153:155, 60:100] = 1
    mask[154:156, 100:120] = 1
    mask[155:156, 120:140] = 1
    mask[212:217, 0:150] = 1
    mask[217:222, 150:256] = 1
    return mask

# %%
from skimage.restoration import inpaint
# obtain the image
mask = get_mask(image)
# Apply inpainting to the damaged image using the mask
restored_image = inpaint.inpaint_biharmonic(image,mask,multichannel=True)
# Show the resulting image
show_img(image)
show_img(restored_image)

# %% [markdown]
# # Removing logos

# %%
image_with_logo = Image.open(r'C:\Users\muham\Downloads\imagelogo.jpg')
image_with_logo = np.array(image_with_logo)

# %%
# Initialize the mask
#mask = np.zeros(image_with_logo.shape[:-1])

# Set the pixels where the logo is to 1
# mask[210:290, 360:425] = 1

# Apply inpainting to remove the logo
#image_logo_removed = inpaint.inpaint_biharmonic(image_with_logo, 
                                                #mask[210:290, 360:425], 
                                                #multichannel=True)

# Show the original and logo removed images
#show_img(image_with_logo, 'Image with logo')
#show_img(image_logo_removed, 'Image with logo removed')

# %% [markdown]
# # Noise

# %%
from skimage.util import random_noise
# add noise to the image
n_image = random_noise(image)
# original vs noise image
show_img(image)
show_img(n_image)

# %% [markdown]
# # Denoising

# %%
from skimage.restoration import denoise_tv_chambolle
# apply total variation filter denoising
denoised_image = denoise_tv_chambolle(n_image, weight=0.1, multichannel=True)
show_img(n_image)
show_img(denoised_image)

# %% [markdown]
# # Biltaeral filter

# %%
from skimage.restoration import denoise_bilateral
denoised_img_b = denoise_bilateral(n_image,multichannel=True)
show_img(denoised_image)
show_img(denoised_img_b)

# %% [markdown]
# # Superpixels & segmentation - Supervised & Unsupervised

# %%
# import the modules
from skimage.segmentation import slic 
from skimage.color import label2rgb
# obtain the segments
segments = slic(image, start_label = 1)
# compare segments of the orignal image 
seg_image = label2rgb(segments, image, kind='avg', bg_label=0)

show_img(image)
show_img(seg_image)

# %%
# Finding contours
image = color.rgb2gray(image)
# Binarize the image
thresh = threshold_otsu(image)
thresh_image = thresh > image
# Out:
# <ipython-input-32-71286e9c20e0>:2: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   image = color.rgb2gray(image)

# %%
# find  counters
from skimage import measure
contours = measure.find_contours(thresh_image, 0.8)
contours = np.array(contours)
# Out:
# <ipython-input-42-ed7cdf6602cf>:4: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   contours = np.array(contours)

# %%
for contour in contours:
    print(contours.shape)
# Out:
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)
# (1014,)

# %%
# Import the modules
from skimage import measure, data, filters

# Obtain the horse image
horse_image = data.horse()

# Find the contours with a constant level value of 0.8
contours = measure.find_contours(horse_image, 0.8)

# Shows the image with contours found
show_img(horse_image, contours)

# %% [markdown]
# # Find contours of an image that is not binary

# %%
# function to find image corners
def show_img_corners(image, coords, title="Corners detected"): 
  plt.imshow(image, interpolation='nearest', cmap='gray') 
  plt.title(title)
  plt.plot(coords[:, 1], coords[:, 0], '+r', markersize=15) 
  plt.axis('off')
  plt.show()

# %%
# A function to show the contour of the image 
def show_image_contour(image, contours):
    plt.figure()
    for n, contour in enumerate(contours):
        plt.plot(contour[:, 1], contour[:, 0], linewidth=3)
    plt.imshow(image, interpolation='nearest', cmap='gray_r')
    plt.title('Contours')
    plt.axis('off')
    plt.show()

# %%
# Make the image grayscale
image = color.rgb2gray(image)

# Obtain the optimal thresh value
thresh = filters.threshold_otsu(image)
# Apply thresholding
binary = image > thresh
# Out:
# <ipython-input-56-2829797d2fa0>:2: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   image = color.rgb2gray(image)

# %%
# Find contours at a constant value of 0.8
contours = measure.find_contours(binary, 0.8)

# Show the image
show_image_contour(image, contours)

# %%
# Create list with the shape of each contour 
shape_contours = [cnt.shape[0] for cnt in contours]

# Set 50 as the maximum size of the dots shape
max_dots_shape = 50

# Count dots in contours excluding bigger than dots size
dots_contours = [cnt for cnt in contours if np.shape(cnt)[0] < max_dots_shape]

# Shows all contours found 
show_image_contour(binary, contours)

# Print the dice's number
print("Dice's dots number: {}. ".format(len(dots_contours)))
# Out:
# Dice's dots number: 1103.

# %% [markdown]
# # Finding the edges with Canny

# %%
from skimage.feature import canny 
# convert image to grayscale
coins = data.coins()
coins = rgb2gray(coins)
# check edges
edges = canny(coins)
show_img(coins)
show_img(edges)
# Out:
# <ipython-input-72-4c538f3ae9e0>:4: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   coins = rgb2gray(coins)

# %%
# less edges
edges = canny(coins, sigma=1.8)
show_img(edges)

# %% [markdown]
# # Right around the corner - Harrsi corner detector

# %%
from skimage.feature import corner_harris, corner_peaks
image = rgb2gray(image)
measure_image = corner_harris(image)
coords = corner_peaks(measure_image, min_distance=5, threshold_rel=0)
# Out:
# <ipython-input-78-2284e66bcc07>:2: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   image = rgb2gray(image)

# %%
print('total of', '', len(coords), 'were detected')
# Out:
# total of  1835 were detected

# %%
show_img_corners(image, coords, title='Corners detected')

# %%
# Import the corner detector related functions and module
from skimage.feature import corner_harris, corner_peaks
rocket_image = data.rocket()
# Convert image from RGB-3 to grayscale
rocket_image_gray = color.rgb2gray(rocket_image)

# Apply the detector  to measure the possible corners
measure_image = corner_harris(building_image_gray)

# Find the peaks of the corners
coords = corner_peaks(measure_image, min_distance=2)

# Show original and resulting image with corners detected
show_img(rocket_image, "Original")
show_img_corners(rocket_image, coords)
# Out:
# <ipython-input-86-ab54d55035a3>:11: FutureWarning: Until version 0.16, threshold_rel was set to 0.1 by default. Starting from version 0.16, the default value is set to None. Until version 0.18, a None value corresponds to a threshold value of 0.1. The default behavior will match skimage.feature.peak_local_max. To avoid this warning, set threshold_rel=0.
#   coords = corner_peaks(measure_image, min_distance=2)

# %%
# Find the peaks with a min distance of 2 pixels
coords_w_min_2 = corner_peaks(measure_image, min_distance=2, threshold_rel=0)
print("With a min_distance set to 2, we detect a total", len(coords_w_min_2), "corners in the image.")
# Out:
# With a min_distance set to 2, we detect a total 4322 corners in the image.

# %% [markdown]
# # Face detection

# %%
# All nessecary functions for face detections
import matplotlib.patches as patches

def crop_face(result, detected, title="Face detected"):
    for d in detected:
        print(d)
        rostro= result[d['r']:d['r']+d['width'], d['c']:d['c']+d['height']]
    
        plt.figure(figsize=(8, 6))
        plt.imshow(rostro)    
        plt.title(title)
        plt.axis('off')
        plt.show()

# %%
def show_detect_face(result, detected, title="Face image"):
    plt.imshow(result)
    img_desc = plt.gca()
    plt.set_cmap('gray')
    plt.title(title)
    plt.axis('off')

    for patch in detected:
        
        img_desc.add_patch(
            patches.Rectangle(
                (patch['c'], patch['r']),
                patch['width'],
                patch['height'],
                fill=False, color='r',linewidth=2))
plt.show()

# %% [markdown]
# # Apply detector on images

# %%
from skimage import data
from skimage.feature import Cascade

import matplotlib.pyplot as plt
from matplotlib import patches

# Load the trained file from the module root.
trained_file = data.lbp_frontal_face_cascade_filename()

# Initialize the detector cascade.
detector = Cascade(trained_file)

img = data.astronaut()

detected = detector.detect_multi_scale(img=img,
                                       scale_factor=1.2,
                                       step_ratio=1,
                                       min_size=(60, 60),
                                       max_size=(90, 500))

plt.imshow(img)
img_desc = plt.gca()
plt.set_cmap('gray')

for patch in detected:

    img_desc.add_patch(
        patches.Rectangle(
            (patch['c'], patch['r']),
            patch['width'],
            patch['height'],
            fill=False,
            color='r',
            linewidth=2
        )
    )

plt.show()

# %% [markdown]
# # Segmentation and face detection

# %%
# Obtain the segmentation with default 100 regions
segments = slic(img)

# Obtain segmented image using label2rgb
segmented_image = label2rgb(segments, img, kind='avg')

# Detect the faces with multi scale method
detected = detector.detect_multi_scale(img=segmented_image, 
                                       scale_factor=1.2, 
                                       step_ratio=1, 
                                       min_size=(10, 10), max_size=(1000, 1000))

# Show the detected faces
show_detected_face(segmented_image, detected)
# Out:
# <ipython-input-177-4115c044a9a3>:2: FutureWarning: skimage.measure.label's indexing starts from 0. In future version it will start from 1. To disable this warning, explicitely set the `start_label` parameter to 1.
#   segments = slic(img)
# <ipython-input-177-4115c044a9a3>:5: FutureWarning: The new recommended value for bg_label is 0. Until version 0.19, the default bg_label value is -1. From version 0.19, the bg_label default value will be 0. To avoid this warning, please explicitly set bg_label value.
#   segmented_image = label2rgb(segments, img, kind='avg')

# %%
# Load the trained file from data
trained_file = data.lbp_frontal_face_cascade_filename()
friends_image = Image.open(r'C:\Users\muham\Downloads\frnds.jfif')
friends_image = np.array(friends_image)
# Initialize the detector cascade
detector = Cascade(trained_file)
# Detect faces with scale factor to 1.2 and step ratio to 1
detected = detector.detect_multi_scale(img=friends_image,
                                       scale_factor=1.2,
                                       step_ratio=1,
                                       min_size=(10, 10),
                                       max_size=(300, 300))
# Show the detected faces
show_detected_face(friends_image, detected)
# Out:
# {'r': 9, 'c': 43, 'width': 35, 'height': 35}
# {'r': 21, 'c': 107, 'width': 30, 'height': 30}
# {'r': 25, 'c': 140, 'width': 26, 'height': 26}
# {'r': 125, 'c': 85, 'width': 36, 'height': 36}
# {'r': 121, 'c': 6, 'width': 44, 'height': 44}

# %%
# functions to merge blurry Faces
def merge_blurry_face(original, gaussain_image):
    # starting points of a face rectangle
    x, y =d['r'], d['c']
    # the width and heigh of a face rectangle
    width, height = d['r'] + d['width'], d['c'] + d['height']
    
    original[x:width, y:height] = gaussain_image
    return original

# %% [markdown]
# # Real-world applications - all shown above

# %%
def getFaceRectangle(image, d):
    ''' Extracts the face from the image using the coordinates of the detected image '''
    # X and Y starting points of the face rectangle
    x, y  = d['r'], d['c']
    
    # The width and height of the face rectangle
    width, height = d['r'] + d['width'],  d['c'] + d['height']
    
    # Extract the detected face
    face= image[ x:width, y:height]
    return face

# %%
#Privacy protection
# Detect the faces
from skimage.filters import gaussian
detected = detector.detect_multi_scale(img=image, 
                                       scale_factor=1.2, step_ratio=1, 
                                       min_size=(10, 10), max_size=(100, 100))
# For each detected face
for d in detected:  
    # Obtain the face rectangle from detected coordinates
    face = getFaceRectangle(image,d)
    
    # Apply gaussian filter to extracted face
    blurred_face = gaussian(face, multichannel=True, sigma = 8)
    
    # Merge this blurry face to our final image and show it
    resulting_image = merge_blurry_face(image, blurred_face) 
show_img(resulting_image, "Blurred faces")

# %%
# Import the necessary modules
from skimage.restoration import denoise_tv_chambolle, inpaint
from skimage.transform import rotate

# Transform the image so it's not rotated
upright_img = rotate(image, 20)

# Remove noise from the image, using the chambolle method
upright_img_without_noise = denoise_tv_chambolle(upright_img,weight=0.1, multichannel=True)

# Reconstruct the image missing parts
mask = get_mask(upright_img)
result = inpaint.inpaint_biharmonic(upright_img_without_noise, mask, multichannel=True)

show_image(result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-213-d86f66e5e75d> in <module>
#      10
#      11 # Reconstruct the image missing parts
# ---> 12 mask = get_mask(upright_img)
#      13 result = inpaint.inpaint_biharmonic(upright_img_without_noise, mask, multichannel=True)
#      14
#
# NameError: name 'get_mask' is not defined
