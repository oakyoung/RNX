# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

# %%
src1 = cv2.imread('./banana1.jpg')

# %%
src2 = cv2.cvtColor(src1, cv2.COLOR_BGR2HSV)

# %% [markdown]
# 69 81 130
# 255 255 255   # Green
#
# 19 0 237 255 255 255  # Yellow
#
# 0  185 215
# 255 255 255   # Red

# %%
# 21 39 183 low H S V
# 255 255 255 High H S V

# %%
low_green = np.array([66, 80, 125])
high_green = np.array([255, 255, 255])

# %%
low_yellow = np.array([19, 37, 181])
high_yellow = np.array([255, 255, 255])

# %%
low_red = np.array([0, 183, 213])
high_red = np.array([255, 255, 255])

# %%
#mask = cv2.inRange(src2, low_green, high_green)
mask = cv2.inRange(src2, low_yellow, high_yellow)
#mask = cv2.inRange(src2, low_red, high_red)

# %%
src1_sub = cv2.bitwise_and(src2, src2, mask = mask)

# %%
cv2_imshow(src1)
cv2_imshow(mask)
cv2_imshow(src1_sub)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183 at 0x7F1A642439D0>
# <PIL.Image.Image image mode=L size=275x183 at 0x7F1A641BAC50>
# <PIL.Image.Image image mode=RGB size=275x183 at 0x7F1A6422B790>

# %%
ret, thr = cv2.threshold(mask, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
cv2_imshow(thr)
print(ret)
# Out:
# <PIL.Image.Image image mode=L size=275x183 at 0x7F1A64246AD0>
# 0.0

# %%
blur = cv2.medianBlur(thr,3)

# %%
cv2_imshow(blur)
# Out:
# <PIL.Image.Image image mode=L size=275x183 at 0x7F1A641D1450>

# %%
cnts, _ = cv2.findContours(blur.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
print(len(cnts))
# Out:
# 2

# %%
copy2 = blur.copy()
count = []
for x in cnts:
    area = cv2.contourArea(x)
    if area > 100:
        count.append(x)
cv2.drawContours(src1, count, -1, (0,255,0), 3)
cv2_imshow(src1)
print("number of lemons found via contour detection = ", len(count))
# Out:
# <PIL.Image.Image image mode=RGB size=275x183 at 0x7F1A641D17D0>
# number of lemons found via contour detection =  1

# %%
for x in cnts:
  area +=cv2.contourArea(x)

# %%
area
# Out:
# 23557.0
